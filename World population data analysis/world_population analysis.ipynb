# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data= pd.read_csv(r'c:\Users\home\desktop\world_population.csv')
data.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia         41128771
# 1   138  ALB         Albania            Tirana    Europe          2842321
# 2    34  DZA         Algeria           Algiers    Africa         44903225
# 3   213  ASM  American Samoa         Pago Pago   Oceania            44273
# 4   203  AND         Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
data.shape
# Out:
# (234, 17)

# %%
len(data["Country"].unique()) #it gives you length
# Out:
# 234

# %%
data.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# ...

# %%
data.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia         41128771
# 1   138  ALB         Albania            Tirana    Europe          2842321
# 2    34  DZA         Algeria           Algiers    Africa         44903225
# 3   213  ASM  American Samoa         Pago Pago   Oceania            44273
# 4   203  AND         Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
data["Continent"].value_counts()
# Out:
# Africa           57
# Asia             50
# Europe           50
# North America    40
# Oceania          23
# South America    14
# Name: Continent, dtype: int64

# %%
data[data["Continent"]== "Asia"] #it gives you all the country name which belongs to asia continent
# Out:
#      Rank CCA3               Country              Capital Continent  \
# 0      36  AFG           Afghanistan                Kabul      Asia
# 9     140  ARM               Armenia              Yerevan      Asia
# 13     91  AZE            Azerbaijan                 Baku      Asia
# 15    154  BHR               Bahrain               Manama      Asia
# 16      8  BGD            Bangladesh                Dhaka      Asia
# 23    165  BTN                Bhutan              Thimphu      Asia
# 29    175  BRN                Brunei  Bandar Seri Begawan      Asia
# 33     73  KHM              Cambodia           Phnom Penh      Asia
# 41      1  CHN                 China              Beijing      Asia
# 73    131  GEO               Georgia              Tbilisi      Asia
# 89    104  HKG             Hong Kong            Hong Kong      Asia
# 92      2  IND                 India            New Delhi      Asia
# 93      4  IDN             Indonesia              Jakarta      Asia
# ...

# %%
data.groupby("Continent").sum() #it sum all the numerical data but continent wise
# Out:
#                Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Africa         5253       1426730932       1360671810       1201102442
# Asia           3878       4721383274       4663086535       4458250182
# Europe         6225        743147538        745792196        741535608
# North America  6437        600296136        594236593        570383850
# Oceania        4336         45038554         43933426         40403283
# South America  1366        436816608        431530043        413134396
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa              1055228072        818946032        638150629
# Asia                4220041327       3735089604       3210563577
# Europe               735613934        726093423        720320797
# North America        542720651        486069584        421266425
# Oceania               37102764         31222778         26743822
# ...

# %%
continent_data = data.groupby("Continent").sum()

# %%
continent_data.head(6)
# Out:
#                Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Africa         5253       1426730932       1360671810       1201102442
# Asia           3878       4721383274       4663086535       4458250182
# Europe         6225        743147538        745792196        741535608
# North America  6437        600296136        594236593        570383850
# Oceania        4336         45038554         43933426         40403283
# South America  1366        436816608        431530043        413134396
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa              1055228072        818946032        638150629
# Asia                4220041327       3735089604       3210563577
# Europe               735613934        726093423        720320797
# North America        542720651        486069584        421266425
# Oceania               37102764         31222778         26743822
# ...

# %%
plt.pie(continent_data["2022 Population"],labels=continent_data.index,autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x20c359fbbe0>,
# ...
#  [Text(0.9307256545524026, 0.5863017618581764, 'Africa'),
#   Text(-1.086464159530947, 0.17203380497656054, 'Asia'),
#   Text(0.4537898168594365, -1.002035329773696, 'Europe'),
#   Text(0.8976684658480467, -0.6357604308401196, 'North America'),
#   Text(1.0287233716949098, -0.3895230731659637, 'Oceania'),
#   Text(1.0837483081113959, -0.18838684844141054, 'South America')],
#  [Text(0.507668538846765, 0.31980096101355077, '17.9%'),
#   Text(-0.5926168142896073, 0.09383662089630573, '59.2%'),
#   Text(0.24752171828696531, -0.5465647253311068, '9.3%'),
#   Text(0.4896373450080254, -0.3467784168218834, '7.5%'),
#   Text(0.5611218391063144, -0.21246713081779836, '0.6%'),
#   Text(0.591135440788034, -0.10275646278622393, '5.5%')])

# %%
data[data["Continent"]=="Asia"][["Country","2022 Population"]]
# Out:
#                   Country  2022 Population
# 0             Afghanistan         41128771
# 9                 Armenia          2780469
# 13             Azerbaijan         10358074
# 15                Bahrain          1472233
# 16             Bangladesh        171186372
# 23                 Bhutan           782455
# 29                 Brunei           449002
# 33               Cambodia         16767842
# 41                  China       1425887337
# 73                Georgia          3744385
# 89              Hong Kong          7488865
# 92                  India       1417173173
# 93              Indonesia        275501339
# 94                   Iran         88550570
# 95                   Iraq         44496122
# 98                 Israel          9038309
# 102                 Japan        123951692
# 104                Jordan         11285869
# 105            Kazakhstan         19397998
# 108                Kuwait          4268873
# 109            Kyrgyzstan          6630623
# ...

# %%
data[data["Continent"]=="Asia"][["Country","2022 Population"]].sort_values(by="2022 Population",ascending=False)
# Out:
#                   Country  2022 Population
# 41                  China       1425887337
# 92                  India       1417173173
# 93              Indonesia        275501339
# 156              Pakistan        235824862
# 16             Bangladesh        171186372
# 102                 Japan        123951692
# 163           Philippines        115559009
# 228               Vietnam         98186856
# 94                   Iran         88550570
# 213                Turkey         85341241
# 206              Thailand         71697030
# 140               Myanmar         54179306
# 194           South Korea         51815810
# 95                   Iraq         44496122
# 0             Afghanistan         41128771
# 182          Saudi Arabia         36408820
# 224            Uzbekistan         34627652
# 122              Malaysia         33938221
# 231                 Yemen         33696614
# 143                 Nepal         30547580
# 151           North Korea         26069416
# ...

# %%
data[data["Continent"]=="Asia"][["Country","2022 Population","1970 Population"]].sort_values(by=["2022 Population","1970 Population"],ascending=False)
# Out:
#                   Country  2022 Population  1970 Population
# 41                  China       1425887337        822534450
# 92                  India       1417173173        557501301
# 93              Indonesia        275501339        115228394
# 156              Pakistan        235824862         59290872
# 16             Bangladesh        171186372         67541860
# 102                 Japan        123951692        105416839
# 163           Philippines        115559009         37435586
# 228               Vietnam         98186856         41928849
# 94                   Iran         88550570         28449705
# 213                Turkey         85341241         35540990
# 206              Thailand         71697030         35791728
# 140               Myanmar         54179306         27284112
# 194           South Korea         51815810         32601143
# 95                   Iraq         44496122          9811347
# 0             Afghanistan         41128771         10752971
# ...

# %%
data[data["Continent"]=="Asia"][["Country","2022 Population"]].sort_values(by="2022 Population",ascending=False,ignore_index=True)
# Out:
#                  Country  2022 Population
# 0                  China       1425887337
# 1                  India       1417173173
# 2              Indonesia        275501339
# 3               Pakistan        235824862
# 4             Bangladesh        171186372
# 5                  Japan        123951692
# 6            Philippines        115559009
# 7                Vietnam         98186856
# 8                   Iran         88550570
# 9                 Turkey         85341241
# 10              Thailand         71697030
# 11               Myanmar         54179306
# 12           South Korea         51815810
# 13                  Iraq         44496122
# 14           Afghanistan         41128771
# 15          Saudi Arabia         36408820
# 16            Uzbekistan         34627652
# 17              Malaysia         33938221
# 18                 Yemen         33696614
# 19                 Nepal         30547580
# 20           North Korea         26069416
# ...

# %%
data[data["Continent"]=="Asia"][["Country","2022 Population"]].sort_values(by="2022 Population",ascending=False,ignore_index=True)[:5]
# Out:
#       Country  2022 Population
# 0       China       1425887337
# 1       India       1417173173
# 2   Indonesia        275501339
# 3    Pakistan        235824862
# 4  Bangladesh        171186372

# %%
asia=data[data["Continent"]=="Asia"][["Country","2022 Population"]].sort_values(by="2022 Population",ascending=False,ignore_index=True)[:5]

# %%
sns.barplot(data=asia,x="Country",y="2022 Population")
# Out:
# <AxesSubplot:xlabel='Country', ylabel='2022 Population'>

# %%
for x in data["Continent"].unique():
    temp=data[data["Continent"] == x][["Country","2022 Population"]].sort_values(by="2022 Population",ascending=False,ignore_index=True)[:5]
    plt.figure(figsize=(8,4))
    plt.title(f"Top 5 Countries based on 2022 Population in {x}")
    sns.barplot(data=temp,x="Country",y="2022 Population")
    plt.show()

# %%
data["Continent"].value_counts()
# Out:
# Africa           57
# Asia             50
# Europe           50
# North America    40
# Oceania          23
# South America    14
# Name: Continent, dtype: int64

# %%
sns.countplot(x="Continent",data=data.sort_values(by="Continent",ascending=False),palette="Set2")
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='count'>

# %%
diff_70_22=data.groupby("Continent")[["1970 Population","2022 Population"]].sum().sort_values(by="Continent",ascending=True).reset_index()

# %%
diff_70_22
# Out:
#        Continent  1970 Population  2022 Population
# 0         Africa        365444348       1426730932
# 1           Asia       2144906290       4721383274
# 2         Europe        655923991        743147538
# 3  North America        315434606        600296136
# 4        Oceania         19480270         45038554
# 5  South America        192947156        436816608

# %%
plt.figure(figsize=(16,4))
plt.plot(diff_70_22["Continent"],diff_70_22["1970 Population"],label="1970",color="red",marker="o")
plt.plot(diff_70_22["Continent"],diff_70_22["2022 Population"],label="2022",color="blue",marker="o")
plt.xlabel("Continent")
plt.ylabel("Population")
plt.grid()
plt.legend()
plt.show()

# %%
data.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia         41128771
# 1   138  ALB         Albania            Tirana    Europe          2842321
# 2    34  DZA         Algeria           Algiers    Africa         44903225
# 3   213  ASM  American Samoa         Pago Pago   Oceania            44273
# 4   203  AND         Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
area=data.groupby("Continent")["Area (km²)"].sum()
plt.pie(area.values,labels=area.index,autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x20c363dd130>,
# ...
#  [Text(0.8412988844954082, 0.7086721293706857, 'Africa'),
#   Text(-0.594842969530374, 0.9252901391457097, 'Asia'),
#   Text(-1.0589878277158473, -0.29756475051603654, 'Europe'),
#   Text(-0.22474887324511, -1.0767952191457082, 'North America'),
#   Text(0.5755579211169315, -0.937407637818018, 'Oceania'),
#   Text(1.0080548783176795, -0.4402560190388411, 'South America')],
#  [Text(0.458890300633859, 0.38654843420219215, '22.3%'),
#   Text(-0.3244598015620221, 0.5047037122612961, '23.6%'),
#   Text(-0.577629724208644, -0.1623080457360199, '16.9%'),
#   Text(-0.12259029449733272, -0.5873428468067499, '17.8%'),
#   Text(0.31394068424559896, -0.5113132569916461, '6.3%'),
#   Text(0.549848115446007, -0.24013964674845872, '13.1%')])

# %%
density=data.groupby("Continent")["Density (per km²)"].sum()
plt.pie(density.values,labels=density.index,autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x20c3643b7c0>,
# ...
#  [Text(1.0754535538522003, 0.2310836504529745, 'Africa'),
#   Text(-0.40226449949512727, 1.0238082205403192, 'Asia'),
#   Text(-0.28331339027197, -1.0628892335952052, 'Europe'),
#   Text(0.9532527614691689, -0.5489163622551289, 'North America'),
#   Text(1.0935958206716418, -0.11852502271469273, 'Oceania'),
#   Text(1.099958195956654, -0.009589950353542223, 'South America')],
#  [Text(0.5866110293739274, 0.12604562751980425, '6.7%'),
#   Text(-0.21941699972461484, 0.5584408475674468, '48.4%'),
#   Text(-0.1545345765119836, -0.5797577637792027, '31.3%'),
#   Text(0.5199560517104557, -0.2994089248664339, '10.3%'),
#   Text(0.5965068112754409, -0.0646500123898324, '2.9%'),
#   Text(0.5999771977945384, -0.00523088201102303, '0.3%')])

# %%
data.groupby("Country")["Area (km²)"].sum().sort_values(ascending=False)[:10]
# Out:
# Country
# Russia           17098242
# Canada            9984670
# China             9706961
# United States     9372610
# Brazil            8515767
# Australia         7692024
# India             3287590
# Argentina         2780400
# Kazakhstan        2724900
# Algeria           2381741
# Name: Area (km²), dtype: int64

# %%
data.groupby("Country")["Density (per km²)"].sum().sort_values(ascending=False)[:20]
# Out:
# Country
# Macau           23172.2667
# Monaco          18234.5000
# Singapore        8416.4634
# Hong Kong        6783.3922
# Gibraltar        5441.5000
# Bahrain          1924.4876
# Maldives         1745.9567
# Malta            1687.6139
# Sint Maarten     1299.2647
# Bermuda          1188.5926
# Bangladesh       1160.0350
# Jersey            954.9828
# Mayotte           871.9278
# Palestine         844.0630
# Guernsey          811.5513
# Taiwan            660.1662
# Barbados          654.9651
# Mauritius         636.9946
# Nauru             603.2381
# Saint Martin      599.8302
# Name: Density (per km²), dtype: float64

# %%
data.groupby("Country")["Growth Rate"].sum().sort_values(ascending=False)[:20]
# Out:
# Country
# Moldova       1.0691
# Poland        1.0404
# Niger         1.0378
# Syria         1.0376
# Slovakia      1.0359
# DR Congo      1.0325
# Mayotte       1.0319
# Chad          1.0316
# Angola        1.0315
# Mali          1.0314
# Somalia       1.0312
# Uganda        1.0304
# Tanzania      1.0300
# Zambia        1.0280
# Mozambique    1.0278
# Benin         1.0274
# Burundi       1.0270
# Sudan         1.0267
# Hungary       1.0265
# Cameroon      1.0263
# Name: Growth Rate, dtype: float64

# %%
data.groupby("Country")["World Population Percentage"].sum().sort_values(ascending=False)[:20]
# Out:
# Country
# China            17.88
# India            17.77
# United States     4.24
# Indonesia         3.45
# Pakistan          2.96
# Nigeria           2.74
# Brazil            2.70
# Bangladesh        2.15
# Russia            1.81
# Mexico            1.60
# Ethiopia          1.55
# Japan             1.55
# Philippines       1.45
# Egypt             1.39
# DR Congo          1.24
# Vietnam           1.23
# Iran              1.11
# Turkey            1.07
# Germany           1.05
# Thailand          0.90
# Name: World Population Percentage, dtype: float64
